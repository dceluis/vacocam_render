# %%
video_path = "/home/luis/workspace/vacocam_render/recipes/source/soccer.mp4"
model_path = "/home/luis/workspace/vacocam_render/recipes/model/soccer_m.pt"

# %%
command = f'../detect.py --model="{model_path}" "{video_path}"'

print(command)

# %run $command

# %%
command = f'../track.py --tracking="declustered" {video_path}'

print(f"%run {command}")

# %run $command
# Out:
# %run ../track.py --tracking="declustered" /home/luis/workspace/vacocam_render/recipes/source/soccer.mp4
# loading detections from /home/luis/workspace/vacocam_render/recipes/source/detect/soccer_detections.npy
# loaded 2400 detections from /home/luis/workspace/vacocam_render/recipes/source/detect/soccer_detections.npy

# %%
command = f'../track.py --tracking="vacocam" --vllm="gemini1.5" {video_path}'

print(f"%run {command}")

# %run $command
# Out:
# %run ../track.py --tracking="vacocam" --vllm="gemini1.5" /home/luis/workspace/vacocam_render/recipes/source/soccer.mp4
# loading detections from /home/luis/workspace/vacocam_render/recipes/source/track/soccer_detections_declustered.npy
# loaded 2400 detections from /home/luis/workspace/vacocam_render/recipes/source/track/soccer_detections_declustered.npy
# Detection count: 64, Clustered count: 63
# Detection count: 25, Clustered count: 20
# Detection count: 48, Clustered count: 46
# Detection count: 40, Clustered count: 40
# Detection count: 74, Clustered count: 70
# Detection count: 44, Clustered count: 36
# Detection count: 91, Clustered count: 91
# Detection count: 65, Clustered count: 63
# Detection count: 177, Clustered count: 175
# Detection count: 97, Clustered count: 97
# Detection count: 25, Clustered count: 23
# Detection count: 10, Clustered count: 5
# Detection count: 32, Clustered count: 31
# Detection count: 90, Clustered count: 90
# ...

# %%
command = f'../render.py --preview --vacocam --width=1920 --height=1080 --framerate=30 --max-zoom=1.9 --min-zoom=1.1 --max-area=400 --min-area=50 {video_path}'

print(f"%run {command}")

# %run $command
# Out:
# %run ../render.py --preview --vacocam --width=1920 --height=1080 --framerate=30 --max-zoom=1.9 --min-zoom=1.1 --max-area=400 --min-area=50 /home/luis/workspace/vacocam_render/recipes/source/soccer.mp4
# Rendering ['/home/luis/workspace/vacocam_render/recipes/source/soccer.mp4'].
# loading detections from /home/luis/workspace/vacocam_render/recipes/source/track/soccer_detections_vacocam.npy
# loaded 2400 detections from /home/luis/workspace/vacocam_render/recipes/source/track/soccer_detections_vacocam.npy
# vacocam deluxe tracking
# /home/luis/workspace/vacocam_render/track.py:191: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   spl_x = UnivariateSpline(range(len(x)), x, w=weights, k=1)
# ...
